# %%
import os
import json
import copy

BASE_DIR = '/home/peter/json_concat/general'

with open(f'{BASE_DIR}/paper2general_ho.json', 'r') as f:
        batch1_data = json.loads(f.read())

with open(f'{BASE_DIR}/batch3_paper2general.json', 'r') as f:
        batch3_data = json.loads(f.read())

with open(f'{BASE_DIR}/paper2general_JH.json', 'r') as f:
        batch2_1_data = json.loads(f.read())

with open(f'{BASE_DIR}/new_paper2general.json', 'r') as f:
        batch2_2_data = json.loads(f.read())

with open(f'{BASE_DIR}/paper2general_MG.json', 'r') as f:
        batch2_3_data = json.loads(f.read())

# %%
train_data = {}
train_data['info'] = copy.deepcopy(batch3_data['info'])
train_data['licenses'] = copy.deepcopy(batch3_data['licenses'])
train_data['categories'] = copy.deepcopy(batch3_data['categories'])
train_data['images'] = []
train_data['annotations'] = []

# %%
# !jq . /content/data/annotations/instances_val2017.json > output.json

# %%
train_data
# Out:
# {'info': {'year': 2021,
#   'version': '1.0',
#   'description': 'Recycle Trash',
#   'contributor': 'Upstage',
#   'url': None,
#   'date_created': '2021-02-02 01:10:00'},
#  'licenses': [{'id': 0,
#    'name': 'CC BY 4.0',
#    'url': 'https://creativecommons.org/licenses/by/4.0/deed.ast'}],
#  'categories': [{'id': 1,
#    'name': 'General trash',
#    'supercategory': 'General trash'},
#   {'id': 2, 'name': 'Paper', 'supercategory': 'Paper'},
#   {'id': 3, 'name': 'Paper pack', 'supercategory': 'Paper pack'},
#   {'id': 4, 'name': 'Metal', 'supercategory': 'Metal'},
#   {'id': 5, 'name': 'Glass', 'supercategory': 'Glass'},
#   {'id': 6, 'name': 'Plastic', 'supercategory': 'Plastic'},
#   {'id': 7, 'name': 'Styrofoam', 'supercategory': 'Styrofoam'},
#   {'id': 8, 'name': 'Plastic bag', 'supercategory': 'Plastic bag'},
#   {'id': 9, 'name': 'Battery', 'supercategory': 'Battery'},
#   {'id': 10, 'name': 'Clothing', 'supercategory': 'Clothing'}],
#  'images': [],
#  'annotations': []}

# %%
img_idx = 0
anno_idx = 0
seg_idx = 0

for img_info in batch1_data['images']:
    img_info['id'] = img_idx
    train_data['images'].append(img_info)
    img_idx += 1

for anno_info in batch1_data['annotations']:
    anno_info['id'] = seg_idx
    train_data['annotations'].append(anno_info)
    seg_idx += 1

cur_seg_id = train_data['annotations'][-1]['id']
cur_img_id = train_data['annotations'][-1]['image_id']
print(f"cur_seg_index: {cur_seg_id}")
print(f"cur_img_index: {cur_img_id}")

print(f"batch2_1 length: {len(batch2_1_data['annotations'])}")
print(f"batch2_1 length: {len(batch2_1_data['images'])}")
for img_info in batch2_1_data['images']:
    img_info['id'] = img_idx
    train_data['images'].append(img_info)
    img_idx += 1

for anno_info in batch2_1_data['annotations']:
    anno_info['id'] = seg_idx 
    train_data['annotations'].append(anno_info)
    seg_idx += 1

cur_seg_id = train_data['annotations'][-1]['id']
cur_img_id = train_data['annotations'][-1]['image_id']
print(f"cur_seg_index: {cur_seg_id}")
print(f"cur_img_index: {cur_img_id}")

print(f"batch2_2 anno_length: {len(batch2_2_data['annotations'])}")
print(f"batch2_2 img_length: {len(batch2_2_data['images'])}")
for img_info in batch2_2_data['images'][:-1]:
    img_info['id'] = img_idx
    train_data['images'].append(img_info)
    img_idx += 1

for anno_info in batch2_2_data['annotations']:
    if anno_info['category_id'] != 0 and anno_info['image_id'] != 2120:
        anno_info['id'] = seg_idx
        train_data['annotations'].append(anno_info)
        seg_idx += 1

cur_seg_id = train_data['annotations'][-1]['id']
cur_img_id = train_data['annotations'][-1]['image_id']
print(f"cur_seg_index: {cur_seg_id}")
print(f"cur_img_index: {cur_img_id}")

print(f"batch2_3 anno_length: {len(batch2_3_data['annotations'])}")
print(f"batch2_3 img_length: {len(batch2_3_data['images'])}")
for img_info in batch2_3_data['images']:
    img_info['id'] = img_idx
    train_data['images'].append(img_info)
    img_idx += 1

for anno_info in batch2_3_data['annotations']:
    if anno_info['category_id'] != 0:
        anno_info['id'] = seg_idx
        train_data['annotations'].append(anno_info)
        seg_idx += 1

cur_seg_id = train_data['annotations'][-1]['id']
cur_img_id = train_data['annotations'][-1]['image_id']
print(f"cur_seg_index: {cur_seg_id}")
print(f"cur_img_index: {cur_img_id}")

print(f"batch3 anno_length: {len(batch3_data['annotations'])}")
print(f"batch3 img_length: {len(batch3_data['images'])}")

temp = copy.deepcopy(img_idx)

for img_info in batch3_data['images']:
    img_info['id'] = img_idx
    train_data['images'].append(img_info)
    img_idx += 1

for anno_info in batch3_data['annotations']:
    if anno_info['category_id'] != 0:
        anno_info['image_id'] += temp 
        anno_info['id'] = seg_idx
        train_data['annotations'].append(anno_info)
        seg_idx += 1

cur_seg_id = train_data['annotations'][-1]['id']
cur_img_id = train_data['annotations'][-1]['image_id']
print(f"cur_seg_index: {cur_seg_id}")
print(f"cur_img_index: {cur_img_id}")
# Out:
# cur_seg_index: 4310
# cur_img_index: 948
# batch2_1 length: 9067
# batch2_1 length: 772
# cur_seg_index: 13377
# cur_img_index: 1720
# batch2_2 anno_length: 5805
# batch2_2 img_length: 400
# cur_seg_index: 19155
# cur_img_index: 2119
# batch2_3 anno_length: 4266
# batch2_3 img_length: 390
# cur_seg_index: 23421
# cur_img_index: 2509
# batch3 anno_length: 3524
# batch3 img_length: 958
# cur_seg_index: 26945
# cur_img_index: 3467

# %%
cur_seg_id = train_data['annotations'][-1]['id']
cur_img_id = train_data['annotations'][-1]['image_id']
print(f"cur_seg_index: {cur_seg_id}")
print(f"cur_img_index: {cur_img_id}")
# Out:
# cur_seg_index: 26945
# cur_img_index: 3467

# %%
train_data['annotations'][-1]
# Out:
# {'image_id': 3467,
#  'category_id': 4,
#  'segmentation': [[314,
#    430,
#    313,
#    430,
#    312,
#    430,
#    311,
#    430,
#    310,
#    430,
#    309,
#    430,
#    309,
#    429,
#    308,
#    429,
#    307,
#    429,
#    306,
#    429,
#    305,
#    429,
#    305,
#    428,
#    304,
#    428,
#    303,
#    428,
#    302,
#    428,
#    301,
#    428,
#    301,
#    427,
#    300,
#    427,
#    299,
#    427,
#    298,
#    427,
#    297,
#    427,
#    297,
#    426,
#    296,
#    426,
#    295,
#    426,
#    294,
#    426,
#    294,
#    425,
#    293,
#    425,
#    292,
#    425,
#    292,
#    424,
#    291,
#    424,
#    290,
#    424,
#    290,
#    423,
#    289,
#    423,
#    288,
#    423,
#    288,
#    422,
#    287,
#    422,
#    286,
#    422,
#    286,
#    421,
#    285,
#    421,
#    284,
#    421,
#    284,
#    420,
#    283,
#    420,
#    283,
#    419,
#    282,
#    419,
#    281,
#    419,
#    281,
#    418,
#    280,
#    418,
#    280,
#    417,
#    279,
#    417,
#    279,
#    416,
#    278,
#    416,
#    277,
#    416,
#    277,
#    415,
#    276,
#    415,
#    276,
#    414,
#    275,
#    414,
#    275,
#    413,
#    274,
#    413,
#    274,
#    412,
#    273,
#    412,
#    273,
#    411,
#    272,
#    411,
#    272,
#    410,
#    271,
#    410,
#    271,
#    409,
#    270,
#    409,
#    270,
#    408,
#    269,
#    408,
#    269,
#    407,
#    268,
#    407,
#    268,
#    406,
#    268,
#    405,
#    267,
#    405,
#    267,
#    404,
#    266,
#    404,
#    266,
#    403,
#    265,
#    403,
#    265,
#    402,
#    264,
#    402,
#    264,
#    401,
#    263,
#    401,
#    263,
#    400,
#    263,
#    399,
#    263,
#    398,
#    263,
#    397,
#    263,
#    396,
#    262,
#    396,
#    262,
#    395,
#    262,
#    394,
#    262,
#    393,
#    262,
#    392,
#    262,
#    391,
#    261,
#    391,
#    261,
#    390,
#    261,
#    389,
#    261,
#    388,
#    260,
#    388,
#    260,
#    387,
#    260,
#    386,
#    259,
#    386,
#    259,
#    385,
#    259,
#    384,
#    259,
#    383,
#    259,
#    382,
#    258,
#    382,
#    258,
#    381,
#    258,
#    380,
#    258,
#    379,
#    258,
#    378,
#    258,
#    377,
#    258,
#    376,
#    258,
#    375,
#    258,
#    374,
#    258,
#    373,
#    258,
#    372,
#    258,
#    371,
#    258,
#    370,
#    258,
#    369,
#    258,
#    368,
#    258,
#    367,
#    258,
#    366,
#    259,
#    365,
#    259,
#    365,
#    259,
#    364,
#    259,
#    363,
#    259,
#    362,
#    259,
#    361,
#    259,
#    360,
#    259,
#    359,
#    259,
#    358,
#    259,
#    357,
#    259,
#    356,
#    259,
#    355,
#    259,
#    354,
#    259,
#    353,
#    260,
#    352,
#    260,
#    352,
#    260,
#    351,
#    260,
#    350,
#    260,
#    349,
#    260,
#    348,
#    260,
#    347,
#    260,
#    346,
#    260,
#    345,
#    260,
#    344,
#    260,
#    343,
#    260,
#    342,
#    260,
#    341,
#    260,
#    340,
#    260,
#    339,
#    261,
#    338,
#    261,
#    338,
#    261,
#    337,
#    261,
#    336,
#    261,
#    335,
#    261,
#    334,
#    261,
#    333,
#    261,
#    332,
#    261,
#    331,
#    261,
#    330,
#    261,
#    329,
#    261,
#    328,
#    261,
#    327,
#    261,
#    326,
#    262,
#    325,
#    262,
#    325,
#    262,
#    324,
#    262,
#    323,
#    262,
#    322,
#    262,
#    321,
#    262,
#    320,
#    262,
#    319,
#    262,
#    318,
#    262,
#    317,
#    262,
#    316,
#    262,
#    315,
#    262,
#    314,
#    262,
#    313,
#    263,
#    312,
#    263,
#    312,
#    263,
#    311,
#    263,
#    310,
#    263,
#    309,
#    263,
#    308,
#    263,
#    307,
#    263,
#    306,
#    263,
#    305,
#    263,
#    304,
#    263,
#    303,
#    263,
#    302,
#    263,
#    301,
#    263,
#    300,
#    264,
#    299,
#    264,
#    299,
#    264,
#    298,
#    264,
#    297,
#    264,
#    296,
#    264,
#    295,
#    264,
#    294,
#    264,
#    293,
#    264,
#    292,
#    264,
#    291,
#    264,
#    290,
#    264,
#    289,
#    264,
#    288,
#    264,
#    287,
#    264,
#    286,
#    265,
#    285,
#    265,
#    285,
#    265,
#    284,
#    265,
#    283,
#    265,
#    282,
#    265,
#    281,
#    265,
#    280,
#    265,
#    279,
#    265,
#    278,
#    265,
#    277,
#    265,
#    276,
#    265,
#    275,
#    265,
#    274,
#    265,
#    273,
#    266,
#    272,
#    266,
#    272,
#    266,
#    271,
#    266,
#    270,
#    266,
#    269,
#    266,
#    268,
#    266,
#    267,
#    266,
#    266,
#    266,
#    265,
#    266,
#    264,
#    266,
#    263,
#    266,
#    262,
#    266,
#    261,
#    266,
#    260,
#    266,
#    259,
#    267,
#    258,
#    267,
#    258,
#    267,
#    257,
#    267,
#    256,
#    267,
#    255,
#    267,
#    254,
#    267,
#    253,
#    267,
#    252,
#    267,
#    251,
#    267,
#    250,
#    267,
#    249,
#    267,
#    248,
#    267,
#    247,
#    267,
#    246,
#    268,
#    245,
#    268,
#    245,
#    268,
#    244,
#    268,
#    243,
#    268,
#    242,
#    268,
#    241,
#    268,
#    240,
#    268,
#    239,
#    268,
#    238,
#    268,
#    237,
#    268,
#    236,
#    268,
#    235,
#    268,
#    234,
#    268,
#    233,
#    268,
#    232,
#    269,
#    231,
#    269,
#    231,
#    269,
#    230,
#    269,
#    229,
#    269,
#    228,
#    269,
#    227,
#    269,
#    226,
#    269,
#    225,
#    269,
#    224,
#    269,
#    223,
#    269,
#    222,
#    269,
#    221,
#    269,
#    220,
#    269,
#    219,
#    269,
#    218,
#    270,
#    217,
#    270,
#    217,
#    270,
#    216,
#    270,
#    215,
#    270,
#    214,
#    270,
#    213,
#    270,
#    212,
#    270,
#    211,
#    270,
#    210,
#    270,
#    209,
#    270,
#    208,
#    270,
#    207,
#    270,
#    206,
#    270,
#    205,
#    271,
#    204,
#    271,
#    204,
#    271,
#    203,
#    271,
#    202,
#    271,
#    201,
#    271,
#    200,
#    271,
#    199,
#    271,
#    198,
#    271,
#    197,
#    271,
#    196,
#    271,
#    195,
#    271,
#    194,
#    271,
#    193,
#    271,
#    192,
#    271,
#    191,
#    271,
#    190,
#    272,
#    189,
#    272,
#    189,
#    272,
#    188,
#    272,
#    187,
#    272,
#    186,
#    272,
#    185,
#    272,
#    184,
#    272,
#    183,
#    272,
#    182,
#    272,
#    181,
#    272,
#    180,
#    272,
#    179,
#    273,
#    178,
#    273,
#    178,
#    273,
#    177,
#    273,
#    176,
#    274,
#    175,
#    274,
#    175,
#    274,
#    174,
#    274,
#    173,
#    274,
#    172,
#    275,
#    171,
#    275,
#    171,
#    275,
#    170,
#    275,
#    169,
#    274,
#    169,
#    274,
#    168,
#    274,
#    167,
#    274,
#    166,
#    274,
#    165,
#    274,
#    164,
#    274,
#    163,
#    275,
#    162,
#    275,
#    162,
#    275,
#    161,
#    276,
#    160,
#    276,
#    160,
#    277,
#    159,
#    278,
#    159,
#    278,
#    159,
#    279,
#    158,
#    280,
#    158,
#    281,
#    158,
#    282,
#    158,
#    283,
#    158,
#    284,
#    158,
#    285,
#    158,
#    286,
#    158,
#    287,
#    158,
#    288,
#    158,
#    289,
#    158,
#    290,
#    158,
#    291,
#    158,
#    292,
#    158,
#    293,
#    158,
#    294,
#    158,
#    295,
#    158,
#    296,
#    158,
#    297,
#    158,
#    298,
#    158,
#    299,
#    158,
#    300,
#    158,
#    301,
#    158,
#    302,
#    158,
#    303,
#    158,
#    304,
#    158,
#    305,
#    158,
#    306,
#    158,
#    307,
#    158,
#    307,
#    159,
#    308,
#    159,
#    309,
#    159,
#    310,
#    159,
#    311,
#    159,
#    312,
#    159,
#    313,
#    159,
#    314,
#    159,
#    315,
#    159,
#    316,
#    159,
#    317,
#    159,
#    318,
#    159,
#    318,
#    160,
#    319,
#    160,
#    320,
#    160,
#    321,
#    160,
#    322,
#    160,
#    323,
#    160,
#    324,
#    160,
#    325,
#    160,
#    325,
#    161,
#    326,
#    161,
#    327,
#    161,
#    328,
#    161,
#    329,
#    161,
#    330,
#    161,
#    331,
#    161,
#    332,
#    161,
#    333,
#    161,
#    333,
#    162,
#    334,
#    162,
#    335,
#    162,
#    336,
#    162,
#    337,
#    162,
#    338,
#    162,
#    339,
#    162,
#    339,
#    163,
#    340,
#    163,
#    341,
#    163,
#    342,
#    163,
#    343,
#    163,
#    344,
#    163,
#    345,
#    163,
#    345,
#    164,
#    346,
#    164,
#    347,
#    164,
#    348,
#    164,
#    348,
#    164,
#    349,
#    163,
#    350,
#    163,
#    351,
#    163,
#    351,
#    163,
#    352,
#    162,
#    353,
#    162,
#    354,
#    162,
#    354,
#    162,
#    355,
#    161,
#    356,
#    161,
#    357,
#    161,
#    357,
#    161,
#    358,
#    160,
#    359,
#    160,
#    360,
#    160,
#    361,
#    160,
#    362,
#    160,
#    362,
#    161,
#    362,
#    162,
#    362,
#    163,
#    362,
#    164,
#    362,
#    164,
#    361,
#    165,
#    361,
#    165,
#    360,
#    166,
#    361,
#    166,
#    361,
#    167,
#    362,
#    167,
#    363,
#    167,
#    364,
#    167,
#    365,
#    167,
#    365,
#    168,
#    366,
#    168,
#    367,
#    168,
#    368,
#    168,
#    369,
#    168,
#    369,
#    169,
#    370,
#    169,
#    371,
#    169,
#    372,
#    169,
#    372,
#    170,
#    373,
#    170,
#    374,
#    170,
#    375,
#    170,
#    376,
#    170,
#    376,
#    171,
#    377,
#    171,
#    378,
#    171,
#    379,
#    171,
#    380,
#    171,
#    380,
#    172,
#    381,
#    172,
#    382,
#    172,
#    382,
#    173,
#    382,
#    174,
#    383,
#    174,
#    383,
#    175,
#    383,
#    176,
#    383,
#    177,
#    383,
#    178,
#    383,
#    179,
#    383,
#    180,
#    383,
#    180,
#    382,
#    181,
#    382,
#    181,
#    381,
#    182,
#    381,
#    183,
#    381,
#    184,
#    381,
#    185,
#    381,
#    186,
#    381,
#    187,
#    381,
#    188,
#    381,
#    189,
#    ...]],
#  'area': 27000.0,
#  'bbox': [258.7, 158.3, 124.9, 272.0],
#  'iscrowd': 0,
#  'id': 26945}

# %%
with open(os.path.join(BASE_DIR, 'train_general.json'), 'w') as f:
    json.dump(train_data, f, indent=4)

# %%
train_data['annotations'][-1]['id']
# Out:
# 26945

# %%
len(train_data['annotations'])
# Out:
# 26946
